# %%
import numpy as np
from binsearch import binary_search

# %%
test_array = np.linspace(0,10,1000)

# %%
# %%timeit
for i in range(10000):
    idx = binary_search(id=4.6,arr=test_array)
# Out:
# 1.94 ms ± 21.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
idx=idx-1
print(test_array[idx-1:idx+2])
# Out:
# [4.59459459 4.6046046  4.61461461]
